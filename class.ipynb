# %%
import pandas as pd

# %%
songs = pd.read_csv(r"C:\Users\sumed\dso576\02-trace\practice_songs.csv")

# %%
growth = songs['w4'] - songs['w1']
growth
#series is 1D df
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# dtype: int64

# %%
songs['w1'].max()
songs.sort_values(by='w1', ascending=False)
#index can be non integer

songs.loc[2] #index (if only one thing)
songs.iloc[2] #position
songs.sort_values(by='w1', ascending=False).iloc[0]
songs.loc[0, 'track']
songs.loc[0, ['track', 'w1']]
songs.iloc[[0,2],[0,1]] #giving row 0 and row 2, and column 0 and column 1
songs.loc[:, ['track', 'w1']] #all rows, but only track and w1 columns
songs.drop_duplicates(subset = 'track', keep = 'first') #drop duplicates based on track column
# Out:
#              track      w1
# 0  Blinding Lights  100000
# 1          Flowers  160000
# 2          Bad Guy  120000
# 3         Espresso   90000
